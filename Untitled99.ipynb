# %% [markdown]
# <a href="https://colab.research.google.com/github/esikianiii/Android_ChatGPT/blob/main/Untitled99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: I'm trying to build a chatbot that can answer questions using the Hugging Face and Python libraries, and provide responses related to sugar based on the database I give it. Guide me step by step from start to finish.

**1. Set up the environment:**

* Install the necessary libraries:

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")
model = AutoModelForCausalLM.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")

def get_answer(question):
  """
  This function takes a question as input and returns an answer using the Hugging Face model.
  """
  inputs = tokenizer(question, return_tensors="pt")
  outputs = model.generate(**inputs)
  answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
  return answer

# Define a function to handle file upload
def handle_file_upload():
  uploaded_file = st.file_uploader("Choose a file")
  if uploaded_file is not None:
    # Process the uploaded file and extract relevant information
    # ...
    # Use the extracted information to generate an answer
    answer = get_answer(extracted_information)
    st.write(answer)

# Define the main function
def main():
  st.title("Zali AI")
  question = st.text_area("Ask me anything")
  if st.button("Get answer"):
    answer = get_answer(question)
    st.write(answer)
  handle_file_upload()

if __name__ == "__main__":
  main()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/434 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.22M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/654M [00:00<?, ?B/s]
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6478f612fd6d> in <cell line: 34>()
# ...

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 37.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...

# %%
import streamlit as st

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")
model = AutoModelForCausalLM.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")

def get_answer(question):
  """
  This function takes a question as input and returns an answer using the Hugging Face model.
  """
  inputs = tokenizer(question, return_tensors="pt")
  outputs = model.generate(**inputs)
  answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
  return answer

# Define a function to handle file upload
def handle_file_upload():
  uploaded_file = st.file_uploader("Choose a file")
  if uploaded_file is not None:
    # Process the uploaded file and extract relevant information
    # ...
    # Use the extracted information to generate an answer
    answer = get_answer(extracted_information)
    st.write(answer)

# Define the main function
def main():
  st.title("Zali AI")
  question = st.text_area("Ask me anything")
  if st.button("Get answer"):
    answer = get_answer(question)
    st.write(answer)
  handle_file_upload()

if __name__ == "__main__":
  main()
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`

# %%
چگونه کد بالا را به برنامه در استریملیت تبدیل کنم
# Out:
#   File "<ipython-input-7-2834782c78e5>", line 1
#     چگونه کد بالا را به برنامه در استریملیت تبدیل کنم
#           ^
# SyntaxError: invalid syntax

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 51.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 11.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.4/312.4 kB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 63.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 8.7 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

def get_answer(question):
  """
  This function takes a question as input and returns an answer using the Hugging Face model.
  """
  # ... (Your existing code)

# Define an interface with a text input and a button
interface = gr.Interface(
  fn=get_answer,
  inputs=[
    gr.Textbox(placeholder="Ask me anything"),
  ],
  outputs=[
    "text",
  ],
)

# Launch the interface
interface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://89efc2e277235e040e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://89efc2e277235e040e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load the Hugging Face model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")
model = AutoModelForCausalLM.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")

def get_answer(question):
  """
  This function takes a question as input and returns an answer using the Hugging Face model.
  """
  inputs = tokenizer(question, return_tensors="pt")
  outputs = model.generate(**inputs)
  answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
  return answer

# Define the interface with a text input and a button
interface = gr.Interface(
  fn=get_answer,
  inputs=[
    gr.Textbox(placeholder="Ask me anything"),
  ],
  outputs=[
    "text",
  ],
)

# Launch the interface
interface.launch()
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://61415024c42e86ca3c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://61415024c42e86ca3c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
